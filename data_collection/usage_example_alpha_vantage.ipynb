# %%
# Program to connect with Alpha Vantage API and fetch the data.

# %% [markdown]
# The following command installs a wrapper for original Alpha Vantage API (https://www.alphavantage.co). The wrapper is more user friendly for Python projects but is maintained by an open-source project and might have bugs. One can refer to https://github.com/RomelTorres/alpha_vantage for latest updates on the API. If needed, one can always use Alpha Vantage API without wrappers which will be more stable.

# %%
# !pip install alpha_vantage
# Out:
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.2.4 is available.
# You should consider upgrading via the 'c:\python3.9.2\python.exe -m pip install --upgrade pip' command.

# %%
from alpha_vantage.timeseries import TimeSeries
import pandas as pd
import numpy as np
import requests

# %%
av_config = {
    "api_key" : "CAJQJUOCIIL391KR",
    "symbol" : "TCS.BSE",
    "opsize" : "compact",
    "opformat" : "pandas"
}

# %%
ts = TimeSeries(key=av_config["api_key"], output_format=av_config["opformat"])
data, meta_data = ts.get_daily_adjusted(symbol=av_config["symbol"], outputsize=av_config["opsize"])

# %%
data
# Out:
#             1. open    2. high     3. low   4. close  5. adjusted close  \
# date
# 2021-09-16  3938.00  3981.5500  3891.9500  3902.5000          3902.5000
# 2021-09-15  3889.95  3980.0000  3866.4500  3954.8000          3954.8000
# 2021-09-14  3849.50  3895.6001  3828.6499  3885.1499          3885.1499
# 2021-09-13  3761.00  3851.8999  3761.0000  3843.8999          3843.8999
# 2021-09-09  3799.00  3809.7000  3765.1499  3791.7500          3791.7500
# ...             ...        ...        ...        ...                ...
# 2021-04-30  3111.00  3132.7000  3021.0000  3038.4000          3017.0258
# 2021-04-29  3142.00  3156.3000  3105.4000  3113.2000          3091.2996
# 2021-04-28  3143.00  3150.5000  3112.0000  3123.8000          3101.8251
# 2021-04-27  3103.00  3135.1000  3103.0000  3131.6000          3109.5702
# 2021-04-26  3109.80  3151.9500  3088.1000  3101.1000          3079.2848
#
#             6. volume  7. dividend amount  8. split coefficient
# date
# ...

# %%
def get_stocksymbol(query):
    url = 'https://www.alphavantage.co/query?function=SYMBOL_SEARCH&keywords={}&apikey={}&datatype=json'.format(requests.utils.quote(query), av_config['api_key'])
    csv_op = requests.get(url)
    return pd.DataFrame(csv_op.json()['bestMatches'])

# %%
csv_op = get_stocksymbol('TATA')

# %%
# Out:
#         1. symbol                            2. name 3. type      4. region  \
# 0   TATASTEEL.BSE                 Tata Steel Limited  Equity   India/Bombay
# 1  TATACONSUM.BSE      Tata Global Beverages Limited  Equity   India/Bombay
# 2  TATAMOTORS.BSE                Tata Motors Limited  Equity   India/Bombay
# 3  TATASTLBSL.BSE                 Tata Steel Bsl Ltd  Equity   India/Bombay
# 4           TTAZF         Tata Consumer Products Ltd  Equity  United States
# 5      532301.BSE                Tata Coffee Limited  Equity   India/Bombay
# 6      500770.BSE             Tata Chemicals Limited  Equity   India/Bombay
# 7      500483.BSE        Tata Communications Limited  Equity   India/Bombay
# 8      500800.BSE     Tata Consumer Products Limited  Equity   India/Bombay
# 9         TCS.BSE  Tata Consultancy Services Limited  Equity   India/Bombay
#
#   5. marketOpen 6. marketClose 7. timezone 8. currency 9. matchScore
# ...

# %%
# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key

url = 'https://www.alphavantage.co/query?function=OVERVIEW&symbol=TATASTEEL.BSE&apikey=CAJQJUOCIIL391KR'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {}

# %%
# !pip install yfinance
# Out:
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.2.4 is available.
# You should consider upgrading via the 'c:\python3.9.2\python.exe -m pip install --upgrade pip' command.
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.63-py2.py3-none-any.whl size=23909 sha256=c9262bcc5f8e575df8f04f0aeffd0c33a34f0513b97d6aa97da5bc6f9b75a0a7
#   Stored in directory: c:\users\ashde\appdata\local\pip\cache\wheels\44\19\52\4db92c8786b13e717b9664529da13bf8d7b74aff580ca64fc0
# ...
#   Created wheel for multitasking: filename=multitasking-0.0.9-py3-none-any.whl size=8368 sha256=7048efcb59dedb17fa04129cd95ad2f0861b8beea6757ffa94c36947b8a367d8
#   Stored in directory: c:\users\ashde\appdata\local\pip\cache\wheels\1d\13\0b\0c32509050dcd9264e9a90b1d9d2dc9c6db9538db151ea7d26
# Successfully built yfinance multitasking
# ...

# %%
import yfinance as yf
tcs = yf.Ticker("TCS.BO")
# Out:
# yfinance.Ticker object <TCS.BO>

# %%
tcs.history(period='1y', interval='1d')
# Out:
#                    Open         High          Low        Close  Volume  \
# Date
# 2020-09-17  2454.346103  2462.241064  2420.397865  2427.750000   83371
# 2020-09-18  2447.438220  2468.162496  2403.769212  2418.572266   57975
# 2020-09-21  2427.701023  2472.110188  2421.385149  2432.240723  127699
# 2020-09-22  2452.175281  2520.466655  2426.171153  2490.416504  264321
# 2020-09-23  2477.044322  2483.952414  2378.357298  2434.756836  238132
# ...                 ...          ...          ...          ...     ...
# 2021-09-13  3761.000000  3851.899902  3761.000000  3843.899902   82516
# 2021-09-14  3849.500000  3895.600098  3828.649902  3885.149902   31541
# 2021-09-15  3889.949951  3980.000000  3866.449951  3954.800049  130664
# 2021-09-16  3938.000000  3981.550049  3891.949951  3902.500000  117036
# 2021-09-17  3930.000000  3944.399902  3806.899902  3830.449951  109484
#
#             Dividends  Stock Splits
# Date
# 2020-09-17        0.0             0
# ...
